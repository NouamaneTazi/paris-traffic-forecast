# %% [markdown]
# # Baseline darts model

# %%
# %reload_ext autoreload
# %autoreload 2

# check if working in colab
try:
    # In colab
    from google.colab import drive
    drive.mount('/content/drive')

    # %cd /content/drive/MyDrive/projects/paris-traffic-forecast
    # %pip install -q darts

except:
    # In local
    # replace with your path
    # %cd /mnt/d/Google Drive/projects/paris-traffic-forecast
# Out:
# /mnt/d/Google Drive/projects/paris-traffic-forecast

# %%
from darts import TimeSeries

import matplotlib.pyplot as plt
from utils import load_data, plot_after


plt.rcParams['figure.figsize'] = [20, 5]
import warnings
warnings.filterwarnings("ignore")
import logging
logging.disable(logging.CRITICAL)

# %% [markdown]
# ## load data

# %%
# import data from csv
path_to_data='data/AV-champs-elysees.csv'
df = load_data(path_to_data)
df
# Out:
#                            Identifiant arc            Libelle  Débit horaire  \
# Date et heure de comptage
# 2020-11-01 03:00:00                   4264  AV_Champs_Elysees           34.0
# 2020-11-01 04:00:00                   4264  AV_Champs_Elysees           40.0
# 2020-11-01 05:00:00                   4264  AV_Champs_Elysees           66.0
# 2020-11-01 06:00:00                   4264  AV_Champs_Elysees          108.0
# 2020-11-01 07:00:00                   4264  AV_Champs_Elysees          126.0
# ...                                    ...                ...            ...
# 2021-11-30 19:00:00                   4264  AV_Champs_Elysees         1311.0
# 2021-11-30 20:00:00                   4264  AV_Champs_Elysees         1195.0
# 2021-11-30 21:00:00                   4264  AV_Champs_Elysees         1154.0
# 2021-11-30 22:00:00                   4264  AV_Champs_Elysees         1049.0
# 2021-11-30 23:00:00                   4264  AV_Champs_Elysees          965.0
#
#                            Taux d'occupation Etat trafic  \
# Date et heure de comptage
# 2020-11-01 03:00:00                  0.40111      Fluide
# 2020-11-01 04:00:00                  0.48389      Fluide
# 2020-11-01 05:00:00                  0.75056      Fluide
# 2020-11-01 06:00:00                  0.99611      Fluide
# 2020-11-01 07:00:00                  1.09889      Fluide
# ...                                      ...         ...
# 2021-11-30 19:00:00                 27.14111  Pré-saturé
# 2021-11-30 20:00:00                 23.34445  Pré-saturé
# 2021-11-30 21:00:00                 17.12945  Pré-saturé
# 2021-11-30 22:00:00                 16.32389  Pré-saturé
# 2021-11-30 23:00:00                 13.15167      Fluide
#
#                            Identifiant noeud amont  \
# Date et heure de comptage
# 2020-11-01 03:00:00                           2294
# 2020-11-01 04:00:00                           2294
# 2020-11-01 05:00:00                           2294
# 2020-11-01 06:00:00                           2294
# 2020-11-01 07:00:00                           2294
# ...                                            ...
# 2021-11-30 19:00:00                           2294
# 2021-11-30 20:00:00                           2294
# 2021-11-30 21:00:00                           2294
# 2021-11-30 22:00:00                           2294
# 2021-11-30 23:00:00                           2294
#
#                                     Libelle noeud amont  \
# 2021-11-30 20:00:00        48.8715358799,2.30172279246
# 2021-11-30 21:00:00        48.8715358799,2.30172279246
# 2021-11-30 22:00:00        48.8715358799,2.30172279246
# 2021-11-30 23:00:00        48.8715358799,2.30172279246
#
#                                                                    geo_shape
# Date et heure de comptage
# 2020-11-01 03:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2020-11-01 04:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2020-11-01 05:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2020-11-01 06:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2020-11-01 07:00:00        {"type": "LineString", "coordinates": [[2.3009...
# ...                                                                      ...
# 2021-11-30 19:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2021-11-30 20:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2021-11-30 21:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2021-11-30 22:00:00        {"type": "LineString", "coordinates": [[2.3009...
# 2021-11-30 23:00:00        {"type": "LineString", "coordinates": [[2.3009...
#
# [9233 rows x 14 columns]

# %%
# transform data to TimeSeries
ts = TimeSeries.from_dataframe(df, 
                          value_cols=["Débit horaire", "Taux d'occupation"],
                          fill_missing_dates=True,
                          freq='H')
ts
# Out:
# <TimeSeries (DataArray) (Date et heure de comptage: 9477, component: 2, sample: 1)>
# array([[[3.400000e+01],
#         [4.011100e-01]],
#
#        [[4.000000e+01],
#         [4.838900e-01]],
#
#        [[6.600000e+01],
#         [7.505600e-01]],
#
#        ...,
#
#        [[1.154000e+03],
#         [1.712945e+01]],
#
#        [[1.049000e+03],
#         [1.632389e+01]],
#
#        [[9.650000e+02],
#         [1.315167e+01]]])
# Coordinates:
#   * Date et heure de comptage  (Date et heure de comptage) datetime64[ns] 202...
#   * component                  (component) object 'Débit horaire' "Taux d'occ...
# Dimensions without coordinates: sample

# %%
# train validation split
train, val = ts.split_before(ts.end_time().__sub__(pd.Timedelta(4, unit='D')))
print(len(train), len(val))
print(train.start_time(), train.end_time())
print(val.start_time(), val.end_time())
train.plot(label='training')
val.plot(label='validation')
plt.legend();
# Out:
# 9380 97
# 2020-11-01 03:00:00 2021-11-26 22:00:00
# 2021-11-26 23:00:00 2021-11-30 23:00:00

# %% [markdown]
# ## Training model

# %%
from darts.models import NaiveSeasonal 

univariate_train = train.univariate_component(0)
univariate_val = val.univariate_component(0)
naive_model = NaiveSeasonal(K=1)
naive_model.fit(univariate_train)
naive_forecast = naive_model.predict(val.n_timesteps)

start_time = naive_forecast.start_time() - pd.Timedelta(1, unit='D')
plot_after(ts, 0, start_time)
plot_after(naive_forecast, 0, start_time, label='Débit horaire naive forecast')
plt.legend();
